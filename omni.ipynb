# %%
import os, shutil, random, pickle
import numpy as np
import matplotlib.pyplot as plt
import skimage.io
from skimage.util import img_as_ubyte

from scipy.optimize import curve_fit
from scipy import stats
from torch.fx.proxy import orig_method_name

# %%
# INPUT_DIR = r"./data/REF_masks101_110/REF_masks101_110/Pos101/PreprocessedPhaseMasks/"
INPUT_DIR = r"./data/REF_raw_data101_110/REF_raw_data101_110/Pos101/aphase"
IMAGE_EXT = ".tiff"  # ".tif" or ".tiff"

SAVE_DIR = os.path.join(INPUT_DIR, "Masks_OMNI")
os.makedirs(SAVE_DIR, exist_ok=True)

INTERVAL_MIN = 2  # 每帧 2 min
PIXEL_SIZE_UM = 0.0733  # 73.3 nm -> 0.0733 um
PIXEL_AREA = PIXEL_SIZE_UM ** 2

FLOW_THRESHOLD = 0.8
CELLPROB_THRESHOLD = 0.0
MIN_SIZE = 250
DIAMETER = None

# %%
files = sorted([
    os.path.join(INPUT_DIR, f)
    for f in os.listdir(INPUT_DIR)
    if f.lower().endswith(IMAGE_EXT)
])

print("Found images:", len(files))
print("First file:", os.path.basename(files[0]) if files else "None")

artifact_mask = skimage.io.imread("./artifact_mask.png")
artifact_mask = artifact_mask.astype(bool)

orig_imgs = []
imgs = []
for f in files:
    orig_im = skimage.io.imread(f)
    bg = np.median(orig_im)
    im = orig_im.copy()
    im[artifact_mask] = bg
    if im.ndim == 3 and im.shape[0] <= 4 and im.shape[0] < min(im.shape[1], im.shape[2]):
        im = im.transpose(1, 2, 0)
    imgs.append(im)
    orig_imgs.append(orig_im)

print("Loaded", len(imgs), "images.")
print("Example shape:", imgs[0].shape if imgs else None)

# show a random frame
idx = random.randrange(len(imgs))
img0 = imgs[idx]
name0 = os.path.splitext(os.path.basename(files[idx]))[0]
print("Showing:", name0)

plt.figure(figsize=(6, 6))
if img0.ndim == 2:
    plt.imshow(img0)
else:
    plt.imshow(img0[..., 0])
plt.axis("off")
plt.title(f"Raw image: {name0}")
plt.show()
# Out:
# Found images: 121
# First file: img_000000000.tiff
# Loaded 121 images.
# Example shape: (782, 499)
# Showing: img_000000007

# %%
import cellpose_omni
import inspect
from cellpose_omni import models

print(cellpose_omni.__file__)
print(models.__file__)
print(inspect.signature(models.Cellpose))
# Out:
# D:\Codes\Python\RM\.venv\Lib\site-packages\cellpose_omni\__init__.py
# D:\Codes\Python\RM\.venv\Lib\site-packages\cellpose_omni\models.py
# (gpu=False, model_type='cyto', net_avg=True, device=None, use_torch=True, model_dir=None, dim=2, omni=None)

# %%
from cellpose_omni import models, core
use_GPU = core.use_gpu()

model = models.CellposeModel(
    gpu=use_GPU,
    pretrained_model="bact_phase_omni",
    model_type="bact_phase_omni",
    nchan=1,
    nclasses=3,
    dim=2,
    omni=True
)
# Out:
# 2025-12-12 02:41:44,022 [INFO] ** TORCH GPU version installed and working. **
# 2025-12-12 02:41:44,022 [WARNING] pretrained model has incorrect path
# 2025-12-12 02:41:44,022 [INFO] >>bact_phase_omni<< model set to be used
# 2025-12-12 02:41:44,022 [INFO] ** TORCH GPU version installed and working. **
# 2025-12-12 02:41:44,022 [INFO] >>>> using GPU

# %%
test_img = imgs[idx]
orig_test_img = orig_imgs[idx]
if test_img.ndim == 3:
    test_img_in = test_img[..., 0]
else:
    test_img_in = test_img

masks, flows, styles = model.eval(
    test_img_in,
    diameter=DIAMETER,
    channels=[0, 0],  # 单通道相位差
    omni=True,
    flow_threshold=FLOW_THRESHOLD,
    cellprob_threshold=CELLPROB_THRESHOLD,
    min_size=MIN_SIZE
)

print("Instances:", int(masks.max()))

# 可视化：原图 + mask（彩色label）
plt.figure(figsize=(12, 8))

plt.subplot(1, 2, 1)
plt.imshow(orig_test_img, cmap="gray")
plt.axis("off")
plt.title("Raw")

cmap = plt.colormaps["nipy_spectral"].copy()
cmap.set_under("black")          # 小于 vmin 的颜色设为黑

plt.subplot(1, 2, 2)
plt.imshow(masks, interpolation="nearest")
plt.axis("off")
plt.title("Instance mask (labels)")

plt.suptitle(f"Test frame: {name0}")
plt.tight_layout()
plt.show()
# Out:
# 2025-12-12 02:41:47,470 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# Instances: 28

# %%
# clean old masks
# if os.path.exists(SAVE_DIR):
#     shutil.rmtree(SAVE_DIR)
# os.makedirs(SAVE_DIR, exist_ok=True)

# %%
pos_areas_pixels = np.zeros(len(imgs), dtype=float)

for i, (img, path) in enumerate(zip(imgs, files)):
    base = os.path.splitext(os.path.basename(path))[0]
    print(f"[{i + 1}/{len(imgs)}] Segmenting {base}")

    if img.ndim == 3:
        img_in = img[..., 0]
    else:
        img_in = img

    masks, flows, styles = model.eval(
        img_in,
        diameter=DIAMETER,
        channels=[0, 0],
        omni=True,
        flow_threshold=FLOW_THRESHOLD,
        cellprob_threshold=CELLPROB_THRESHOLD,
        min_size=MIN_SIZE
    )

    labels = masks.astype(np.uint16)

    counts = np.unique(labels, return_counts=True)[1][1:]
    pos_areas_pixels[i] = counts.sum()

    # save mask（background=0，instance=1,2,3...）
    out_mask = os.path.join(SAVE_DIR, f"MASK_{base}.tif")
    skimage.io.imsave(out_mask, labels, check_contrast=False)

# save areas
with open(os.path.join(SAVE_DIR, "growth_areas.pickle"), "wb") as f:
    pickle.dump(pos_areas_pixels, f)

print("Saved masks to:", SAVE_DIR)
print("Saved growth_areas.pickle:", os.path.join(SAVE_DIR, "growth_areas.pickle"))
print("Area sample (pixels):", pos_areas_pixels[:10])
# Out:
# [1/121] Segmenting img_000000000
# 2025-12-12 01:30:37,154 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [2/121] Segmenting img_000000001
# 2025-12-12 01:30:37,704 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [3/121] Segmenting img_000000002
# 2025-12-12 01:30:38,065 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [4/121] Segmenting img_000000003
# 2025-12-12 01:30:38,414 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [5/121] Segmenting img_000000004
# 2025-12-12 01:30:38,767 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [6/121] Segmenting img_000000005
# 2025-12-12 01:30:39,140 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [7/121] Segmenting img_000000006
# 2025-12-12 01:30:39,485 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [8/121] Segmenting img_000000007
# 2025-12-12 01:30:39,862 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [9/121] Segmenting img_000000008
# 2025-12-12 01:30:40,255 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [10/121] Segmenting img_000000009
# 2025-12-12 01:30:40,621 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [11/121] Segmenting img_000000010
# 2025-12-12 01:30:41,011 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [12/121] Segmenting img_000000011
# 2025-12-12 01:30:41,415 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [13/121] Segmenting img_000000012
# 2025-12-12 01:30:41,783 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [14/121] Segmenting img_000000013
# 2025-12-12 01:30:42,123 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [15/121] Segmenting img_000000014
# 2025-12-12 01:30:42,466 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [16/121] Segmenting img_000000015
# 2025-12-12 01:30:42,819 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [17/121] Segmenting img_000000016
# 2025-12-12 01:30:43,167 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [18/121] Segmenting img_000000017
# 2025-12-12 01:30:43,511 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [19/121] Segmenting img_000000018
# 2025-12-12 01:30:43,896 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [20/121] Segmenting img_000000019
# 2025-12-12 01:30:44,248 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [21/121] Segmenting img_000000020
# 2025-12-12 01:30:44,596 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [22/121] Segmenting img_000000021
# 2025-12-12 01:30:44,947 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [23/121] Segmenting img_000000022
# 2025-12-12 01:30:45,324 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [24/121] Segmenting img_000000023
# 2025-12-12 01:30:45,665 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [25/121] Segmenting img_000000024
# 2025-12-12 01:30:46,056 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [26/121] Segmenting img_000000025
# 2025-12-12 01:30:46,453 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [27/121] Segmenting img_000000026
# 2025-12-12 01:30:46,851 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [28/121] Segmenting img_000000027
# 2025-12-12 01:30:47,248 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [29/121] Segmenting img_000000028
# 2025-12-12 01:30:47,633 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [30/121] Segmenting img_000000029
# 2025-12-12 01:30:48,012 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [31/121] Segmenting img_000000030
# 2025-12-12 01:30:48,391 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [32/121] Segmenting img_000000031
# 2025-12-12 01:30:48,782 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [33/121] Segmenting img_000000032
# 2025-12-12 01:30:49,172 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [34/121] Segmenting img_000000033
# 2025-12-12 01:30:49,513 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [35/121] Segmenting img_000000034
# 2025-12-12 01:30:49,851 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [36/121] Segmenting img_000000035
# 2025-12-12 01:30:50,201 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [37/121] Segmenting img_000000036
# 2025-12-12 01:30:50,551 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [38/121] Segmenting img_000000037
# 2025-12-12 01:30:50,903 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [39/121] Segmenting img_000000038
# 2025-12-12 01:30:51,294 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [40/121] Segmenting img_000000039
# 2025-12-12 01:30:51,642 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [41/121] Segmenting img_000000040
# 2025-12-12 01:30:51,998 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [42/121] Segmenting img_000000041
# 2025-12-12 01:30:52,342 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [43/121] Segmenting img_000000042
# 2025-12-12 01:30:52,692 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [44/121] Segmenting img_000000043
# 2025-12-12 01:30:53,043 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [45/121] Segmenting img_000000044
# 2025-12-12 01:30:53,447 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [46/121] Segmenting img_000000045
# 2025-12-12 01:30:53,828 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [47/121] Segmenting img_000000046
# 2025-12-12 01:30:54,232 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [48/121] Segmenting img_000000047
# 2025-12-12 01:30:54,623 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [49/121] Segmenting img_000000048
# 2025-12-12 01:30:55,017 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [50/121] Segmenting img_000000049
# 2025-12-12 01:30:55,645 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [51/121] Segmenting img_000000050
# 2025-12-12 01:30:56,042 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [52/121] Segmenting img_000000051
# 2025-12-12 01:30:56,447 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [53/121] Segmenting img_000000052
# 2025-12-12 01:30:56,858 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [54/121] Segmenting img_000000053
# 2025-12-12 01:30:57,272 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [55/121] Segmenting img_000000054
# 2025-12-12 01:30:57,672 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [56/121] Segmenting img_000000055
# 2025-12-12 01:30:58,111 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [57/121] Segmenting img_000000056
# 2025-12-12 01:30:58,516 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [58/121] Segmenting img_000000057
# 2025-12-12 01:30:58,938 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [59/121] Segmenting img_000000058
# 2025-12-12 01:30:59,338 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [60/121] Segmenting img_000000059
# 2025-12-12 01:30:59,727 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [61/121] Segmenting img_000000060
# 2025-12-12 01:31:00,110 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [62/121] Segmenting img_000000061
# 2025-12-12 01:31:00,487 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [63/121] Segmenting img_000000062
# 2025-12-12 01:31:00,872 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [64/121] Segmenting img_000000063
# 2025-12-12 01:31:01,242 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [65/121] Segmenting img_000000064
# 2025-12-12 01:31:01,652 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [66/121] Segmenting img_000000065
# 2025-12-12 01:31:02,055 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [67/121] Segmenting img_000000066
# 2025-12-12 01:31:02,468 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [68/121] Segmenting img_000000067
# 2025-12-12 01:31:02,867 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [69/121] Segmenting img_000000068
# 2025-12-12 01:31:03,287 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [70/121] Segmenting img_000000069
# 2025-12-12 01:31:03,700 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [71/121] Segmenting img_000000070
# 2025-12-12 01:31:04,111 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [72/121] Segmenting img_000000071
# 2025-12-12 01:31:04,510 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [73/121] Segmenting img_000000072
# 2025-12-12 01:31:04,875 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [74/121] Segmenting img_000000073
# 2025-12-12 01:31:05,232 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [75/121] Segmenting img_000000074
# 2025-12-12 01:31:05,604 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [76/121] Segmenting img_000000075
# 2025-12-12 01:31:05,991 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [77/121] Segmenting img_000000076
# 2025-12-12 01:31:06,352 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [78/121] Segmenting img_000000077
# 2025-12-12 01:31:06,752 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [79/121] Segmenting img_000000078
# 2025-12-12 01:31:07,132 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [80/121] Segmenting img_000000079
# 2025-12-12 01:31:07,506 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [81/121] Segmenting img_000000080
# 2025-12-12 01:31:07,884 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [82/121] Segmenting img_000000081
# 2025-12-12 01:31:08,273 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [83/121] Segmenting img_000000082
# 2025-12-12 01:31:08,680 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [84/121] Segmenting img_000000083
# 2025-12-12 01:31:09,102 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [85/121] Segmenting img_000000084
# 2025-12-12 01:31:09,518 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [86/121] Segmenting img_000000085
# 2025-12-12 01:31:09,927 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [87/121] Segmenting img_000000086
# 2025-12-12 01:31:10,318 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [88/121] Segmenting img_000000087
# 2025-12-12 01:31:10,701 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [89/121] Segmenting img_000000088
# 2025-12-12 01:31:11,105 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [90/121] Segmenting img_000000089
# 2025-12-12 01:31:11,543 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [91/121] Segmenting img_000000090
# 2025-12-12 01:31:11,932 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [92/121] Segmenting img_000000091
# 2025-12-12 01:31:12,324 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [93/121] Segmenting img_000000092
# 2025-12-12 01:31:12,708 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [94/121] Segmenting img_000000093
# 2025-12-12 01:31:13,089 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [95/121] Segmenting img_000000094
# 2025-12-12 01:31:13,501 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [96/121] Segmenting img_000000095
# 2025-12-12 01:31:13,938 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [97/121] Segmenting img_000000096
# 2025-12-12 01:31:14,320 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [98/121] Segmenting img_000000097
# 2025-12-12 01:31:14,702 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [99/121] Segmenting img_000000098
# 2025-12-12 01:31:15,092 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [100/121] Segmenting img_000000099
# 2025-12-12 01:31:15,487 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [101/121] Segmenting img_000000100
# 2025-12-12 01:31:15,922 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [102/121] Segmenting img_000000101
# 2025-12-12 01:31:16,342 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [103/121] Segmenting img_000000102
# 2025-12-12 01:31:16,736 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [104/121] Segmenting img_000000103
# 2025-12-12 01:31:17,177 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [105/121] Segmenting img_000000104
# 2025-12-12 01:31:17,601 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [106/121] Segmenting img_000000105
# 2025-12-12 01:31:18,035 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [107/121] Segmenting img_000000106
# 2025-12-12 01:31:18,458 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [108/121] Segmenting img_000000107
# 2025-12-12 01:31:18,908 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [109/121] Segmenting img_000000108
# 2025-12-12 01:31:19,334 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [110/121] Segmenting img_000000109
# 2025-12-12 01:31:19,762 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [111/121] Segmenting img_000000110
# 2025-12-12 01:31:20,160 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [112/121] Segmenting img_000000111
# 2025-12-12 01:31:20,552 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [113/121] Segmenting img_000000112
# 2025-12-12 01:31:20,962 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [114/121] Segmenting img_000000113
# 2025-12-12 01:31:21,398 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [115/121] Segmenting img_000000114
# 2025-12-12 01:31:21,797 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [116/121] Segmenting img_000000115
# 2025-12-12 01:31:22,211 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [117/121] Segmenting img_000000116
# 2025-12-12 01:31:22,597 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [118/121] Segmenting img_000000117
# 2025-12-12 01:31:23,002 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [119/121] Segmenting img_000000118
# 2025-12-12 01:31:23,447 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [120/121] Segmenting img_000000119
# 2025-12-12 01:31:23,905 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# [121/121] Segmenting img_000000120
# 2025-12-12 01:31:24,344 [WARNING] cellprob_threshold and dist_threshold are being deprecated in a future release, use mask_threshold instead
# Saved masks to: ./data/REF_raw_data101_110/REF_raw_data101_110/Pos101/aphase\Masks_OMNI
# Saved growth_areas.pickle: ./data/REF_raw_data101_110/REF_raw_data101_110/Pos101/aphase\Masks_OMNI\growth_areas.pickle
# Area sample (pixels): [13146. 13842. 13794. 14458. 14978. 13660. 14413. 15595. 15252. 14878.]

# %%
time_h = np.arange(len(pos_areas_pixels)) * (INTERVAL_MIN / 60.0)

pos_areas_um2 = pos_areas_pixels * PIXEL_AREA

plt.figure(figsize=(7, 4), facecolor="white")
plt.plot(time_h, pos_areas_pixels, lw=2)
plt.xlabel("Time (h)")
plt.ylabel("Total area (pixels)")
plt.title("Area growth (pixels)")
plt.grid(alpha=0.2)
plt.show()

# save figure
plt.figure(figsize=(7, 4), facecolor="white")
plt.plot(time_h, pos_areas_um2, lw=2)
plt.xlabel("Time (h)")
plt.ylabel(r"Total area ($\mu m^2$)")
plt.title("Area growth (Omnipose)")
plt.grid(alpha=0.2)
plt.savefig(os.path.join(SAVE_DIR, "Area_growth_omni.svg"), bbox_inches="tight")
plt.show()

print("Saved:", os.path.join(SAVE_DIR, "Area_growth_omni.svg"))
# Out:
# Saved: ./data/REF_raw_data101_110/REF_raw_data101_110/Pos101/aphase\Masks_OMNI\Area_growth_omni.svg

# %%
def exp_growth_fit(x, a, b):
    return a * np.exp(b * x)

ROLLING_NUMBER = 16

areas = pos_areas_um2.copy()

growth_rates = []
fit_ok = 0

for i in range(ROLLING_NUMBER, len(areas)):
    x = np.arange(ROLLING_NUMBER)
    y = areas[i - ROLLING_NUMBER:i]

    if np.any(y <= 0):
        growth_rates.append(np.nan)
        continue

    p0 = [y[0], 0.001]
    try:
        popt, _ = curve_fit(exp_growth_fit, x, y, p0=p0, maxfev=5000)
        b_per_frame = popt[1]
        b_per_hour = b_per_frame * (60.0 / INTERVAL_MIN)
        growth_rates.append(b_per_hour)
        fit_ok += 1
    except RuntimeError:
        growth_rates.append(np.nan)

growth_rates = np.array(growth_rates, dtype=float)

print("Growth rate length:", len(growth_rates))
print("Fits ok:", fit_ok, "/", len(growth_rates))
print("Example growth rates:", growth_rates[~np.isnan(growth_rates)][:10])

time_gr_h = np.arange(ROLLING_NUMBER, len(areas)) * (INTERVAL_MIN / 60.0)
# 保存 growth rate 数组
with open(os.path.join(SAVE_DIR, "growth_rate_rolling.pickle"), "wb") as f:
    pickle.dump(growth_rates, f)

plt.figure(figsize=(7, 4), facecolor="white")
plt.plot(time_gr_h, growth_rates, lw=2)
plt.xlabel("Time (h)")
plt.ylabel(r"Growth rate ($h^{-1}$)")
plt.title("Growth rate (Omnipose)")
plt.ylim(-0.5, 1.5)
plt.grid(alpha=0.2)
plt.savefig(os.path.join(SAVE_DIR, "Growth_rate_omni.svg"), bbox_inches="tight")
plt.show()

print("Saved:", os.path.join(SAVE_DIR, "growth_rate_rolling.pickle"))
print("Saved:", os.path.join(SAVE_DIR, "Growth_rate_omni.svg"))
# Out:
# Growth rate length: 105
# Fits ok: 105 / 105
# Example growth rates: [0.24608148 0.17034726 0.10587132 0.08456178 0.08876203 0.10645223
#  0.08626162 0.09027521 0.14370279 0.20038925]
# Saved: ./data/REF_raw_data101_110/REF_raw_data101_110/Pos101/aphase\Masks_OMNI\growth_rate_rolling.pickle
# Saved: ./data/REF_raw_data101_110/REF_raw_data101_110/Pos101/aphase\Masks_OMNI\Growth_rate_omni.svg

# %%
# select 6 frame for sampling
n_show = 6
idxs = np.linspace(0, len(imgs) - 1, n_show).astype(int)

plt.figure(figsize=(24, 8), facecolor="white")

for k, i in enumerate(idxs):
    img = imgs[i]
    if img.ndim == 3:
        img_in = img[..., 0]
    else:
        img_in = img

    base = os.path.splitext(os.path.basename(files[i]))[0]
    mask_path = os.path.join(SAVE_DIR, f"MASK_{base}.tif")
    m = skimage.io.imread(mask_path)

    plt.subplot(2, n_show, k + 1)
    plt.imshow(img_in)
    plt.axis("off")
    plt.title(f"t={i}")

    plt.subplot(2, n_show, n_show + k + 1)
    plt.imshow(m, interpolation="nearest")
    plt.axis("off")
    plt.title(f"labels max={m.max()}")

plt.tight_layout()
plt.show()
